# %% [markdown]
# <a href="https://colab.research.google.com/github/Gail529/Visualizations/blob/master/insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data=pd.read_csv('/content/Train.csv')
data.head(5)
# Out:
#         ID join_date sex marital_status  ...  JZ9D J9JW GHYX ECY3
# 0  4WKQSBB  1/2/2019   F              M  ...     0    0    0    0
# 1  CP5S02H  1/6/2019   F              M  ...     0    0    0    0
# 2  2YKDILJ  1/6/2013   M              U  ...     0    0    0    1
# 3  2S9E81J  1/8/2019   M              M  ...     0    0    0    0
# 4  BHDYVFT  1/8/2019   M              M  ...     1    1    0    0
#
# [5 rows x 29 columns]

# %%
data.describe()

# %%
 
data['birth_year'].nunique()
# Out:
# 61

# %%
data.info()

# %%
corr=data.corr()
plt.figure(figsize=(12,12))
sns.set(style='darkgrid')
sns.heatmap(corr,annot=True,   fmt='.1f',  linewidth=.5  ,square=True )

# %%
sns.set(style='darkgrid',color_codes=True,palette='deep')
sns.distplot(data['birth_year'],hist=True,bins=10);

# %%
sns.set(style='darkgrid',color_codes=True,palette='deep')
sns.countplot(data['sex'])

# %%
sns.set(style='darkgrid',color_codes=True,palette='deep')
sns.countplot(data['marital_status'])

# %%
plt.figure(figsize=(9,5))
sns.set(style='darkgrid',color_codes=True,palette='deep')
sns.countplot(data['branch_code'])

# %%
plt.figure(figsize=(9,5))
sns.set(style='darkgrid',color_codes=True,palette='deep')
sns.countplot(data['occupation_category_code'])

# %%
data['occupation_code'].value_counts()
# Out:
# 2A7I    7089
# 0KID    3969
# SST3    2711
# UJ5T    2079
# 0OJM    1565
#         ...
# CEL6       1
# W3ZV       1
# YJXM       1
# WSRG       1
# VYSA       1
# Name: occupation_code, Length: 233, dtype: int64
